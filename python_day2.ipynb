# %%
first_name = 'Sanket'
print(first_name)
# Out:
# Sanket

# %%
last_name = "Dangat"
print(last_name)
# Out:
# Dangat

# %%
fullname = 'Sanket Dangat'

print(fullname)
# Out:
# Sanket Dangat

# %%
fullname = 'sanket dangat'

print(fullname.title())
# Out:
# Sanket Dangat

# %%
print(fullname.upper())
# Out:
# SANKET DANGAT

# %%
print(fullname.lower())
# Out:
# sanket dangat

# %%
type(fullname)
