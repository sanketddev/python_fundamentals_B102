# %%
# f-string

# %%
fname = 'sanket'
lname = 'dangat'

fullname = f"My name is {fname} {lname}"

print(fullname)
# Out:
# My name is sanket dangat

# %%
fullname = f"My name is {fname.title()} {lname.title()}"

print(fullname)
# Out:
# My name is Sanket Dangat

# %%
# Adding whitespaces to stirng

# %%
print("Cloud Provider:awsazuregcporacle")
# Out:
# Cloud Provider:awsazuregcporacle

# %%
print("Cloud Provider:\naws\nazure\ngcp\noracle")
# Out:
# Cloud Provider:
# aws
# azure
# gcp
# oracle

# %%
# \n : new line

# \t: tab

# %%
print("Cloud Provider:\n\taws\n\tazure\n\tgcp\n\toracle")
# Out:
# Cloud Provider:
# 	aws
# 	azure
# 	gcp
# 	oracle

# %%
# Removing whitespace from strings

# %%
tool1= '     jenkins'
print(tool1)
# Out:
#      jenkins

# %%
tool1.lstrip()
# Out:
# 'jenkins'

# %%
tool2 = 'git     '
print(tool2)
# Out:
# git

# %%
tool2.rstrip()
# Out:
# 'git'

# %%
tool3= '     docker     '
print(tool3)
# Out:
#      docker

# %%
tool3.strip()
# Out:
# 'docker'

# %%
num = 66655
print(num)
# Out:
# 66655

# %%
type(num)
# Out:
# int

# %%
num2 = -2.555
print(num2)
# Out:
# -2.555

# %%
type(num2)
# Out:
# float
